# %%
mpl.matplotlib_fname()
# Out:
# '/home/vagrant/.config/matplotlib/matplotlibrc'

# %%
mpl.get_configdir()
# Out:
# '/home/vagrant/.config/matplotlib'

# %%
import matplotlib.font_manager as fm

# %%
fm.findSystemFonts()
# Out:
# ['/home/vagrant/.fonts/IPAexfont00301/ipaexm.ttf',
#  '/usr/share/fonts/ipa-mincho/ipam.ttf',
#  '/usr/share/fonts/ipa-pgothic/ipagp.ttf',
#  '/usr/share/fonts/ipa-pmincho/ipamp.ttf',
#  '/home/vagrant/.fonts/IPAexfont00301/ipaexg.ttf',
#  '/usr/share/fonts/ipa-gothic/ipag.ttf']

# %%
# -*- coding: utf-8 -*-
import re
from time import sleep
from bs4 import BeautifulSoup
import requests
import MeCab as mc
import feedparser
from crawllist import *
import urllib
from collections import Counter
import redis
r = redis.StrictRedis(host='localhost', port=6379, db=0)
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, date, timedelta
slothlib_path = 'http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt'
slothlib_file = urllib.request.urlopen(slothlib_path)
slothlib_stopwords = [line.decode("utf-8").strip() for line in slothlib_file]
stop_words = [ss for ss in slothlib_stopwords if not ss==u'']

# %%
mpl.rcParams["font.family"]
# Out:
# ['IPAexGothic']

# %%
rens = r.zrevrange(“all_urls/2018-08-19”,0,-1,withscores=True)
arnoldoy = [ren[1] for ren in rens ]
arnoldox = [ren[0].decode('utf-8') for ren in rens ]
arnoldo = [(ren[0].decode('utf-8'),ren[1]) for ren in rens ]
# Out:
#   File "<ipython-input-5-76c8a47f3b89>", line 1
#     rens = r.zrevrange(“all_urls/2018-08-19”,0,-1,withscores=True)
#                                ^
# SyntaxError: invalid character in identifier

# %%
rens = r.zrevrange("all_urls/2018-08-25",0,-1,withscores=True)
arnoldoy = [ren[1] for ren in rens ]
arnoldox = [ren[0].decode('utf-8') for ren in rens ]
arnoldo = [(ren[0].decode('utf-8'),ren[1]) for ren in rens ]

# %%
arnoldo
# Out:
# [('米', 4.0),
#  ('氏', 3.0),
#  ('東京', 3.0),
#  ('女性', 3.0),
#  ('2', 3.0),
#  ('麺', 2.0),
#  ('雇用', 2.0),
#  ('障害', 2.0),
#  ('都心', 2.0),
#  ('邦人', 2.0),
#  ('発見', 2.0),
#  ('減', 2.0),
#  ('死亡', 2.0),
#  ('止め', 2.0),
#  ('日本人', 2.0),
#  ('日本', 2.0),
#  ('撃た', 2.0),
#  ('島', 2.0),
#  ('家賃', 2.0),
#  ('即席', 2.0),
#  ('世界', 2.0),
#  ('上昇', 2.0),
#  ('パリ', 2.0),
#  ('セブ', 2.0),
#  ('キャンベル', 2.0),
#  ('れ', 2.0),
#  ('V', 2.0),
#  ('?', 2.0),
#  ('1', 2.0),
#  ('風花', 1.0),
#  ('静岡', 1.0),
#  ('電子', 1.0),
#  ('難民', 1.0),
#  ('離脱', 1.0),
#  ('離婚', 1.0),
#  ('関東', 1.0),
#  ('長期', 1.0),
#  ('長官', 1.0),
#  ('銀', 1.0),
#  ('遺跡', 1.0),
#  ('運転', 1.0),
#  ('通話', 1.0),
#  ('通報', 1.0),
#  ('途絶え', 1.0),
#  ('逆風', 1.0),
#  ('逃走', 1.0),
#  ('足取り', 1.0),
#  ('買収', 1.0),
#  ('読む', 1.0),
#  ('語学', 1.0),
#  ('訪朝', 1.0),
#  ('西川', 1.0),
#  ('西友', 1.0),
#  ('裏側', 1.0),
#  ('行列', 1.0),
#  ('虚偽', 1.0),
#  ('虐待', 1.0),
#  ('菜', 1.0),
#  ('英', 1.0),
#  ('芸能人', 1.0),
#  ('舞台', 1.0),
#  ('自殺', 1.0),
# ...

# %%
df = pd.DataFrame({"word_count":arnoldoy,"word":arnoldox})

# %%
df["word_count"] = df["word_count"].apply(lambda count: int(count))

# %%
# -*- coding: utf-8 -*-
mpl.rcParams['axes.xmargin'] = 0
mpl.rcParams['axes.ymargin'] = 0
word=df["word"]
y_pos = np.arange(len(word))

fig, ax = plt.subplots(figsize=(12,len(word)/4))
ax.barh(y_pos,df["word_count"],height=0.4)
ax.set_yticks(y_pos)
ax.set_yticklabels(word)
#ax.set_ylabel(word)

ax.invert_yaxis()
